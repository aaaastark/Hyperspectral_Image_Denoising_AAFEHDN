# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import re
import os, glob, datetime, time
import shutil
import random
import math
from skimage.metrics import peak_signal_noise_ratio, structural_similarity
from matplotlib import pyplot as plt

import scipy.io
import scipy.ndimage
import numpy as np
import seaborn as sns
import plotly.express as px

import torch
from torch import nn, einsum
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import MultiStepLR
from tqdm import tqdm
import torch.nn.init as init
import torch.nn.functional as F

# %matplotlib inline

# %%
seed = 123789
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
np.random.seed(seed)  # Numpy module.
random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
os.environ['PYTHONHASHSEED'] = str(seed)

# %%
def sam(x_true, x_pred):
    assert x_true.ndim ==3 and x_true.shape == x_pred.shape
    h,w,c=x_pred.shape
    sam_rad = []
    for x in range(x_true.shape[0]):
        for y in range(x_true.shape[1]):
            tmp_pred = x_pred[x, y].ravel()
            tmp_true = x_true[x, y].ravel()

            s = np.sum(np.dot(tmp_pred, tmp_true))
            t = (np.sqrt(np.sum(tmp_pred ** 2))) * (np.sqrt(np.sum(tmp_true ** 2)))
            th = np.arccos(s/t)
            sam_rad.append(th)
    sam_deg = np.mean(sam_rad)
    return sam_deg

def quantitative_assess(data_clean,test_out):
    psnrs=[]
    ssims=[]
    height,width,band =data_clean.shape
    for b in range(band):
        psnr1 = peak_signal_noise_ratio(data_clean[:, :, b], test_out[:, :, b],data_range=1)
        ssim1 = structural_similarity(data_clean[:, :, b], test_out[:, :, b],win_size=11,data_range=1,gaussian_weights=1)

        psnrs.append(psnr1)
        ssims.append(ssim1)
    avg_psnr = np.mean(psnrs)
    avg_ssim = np.mean(ssims)
    Sam=sam(data_clean,test_out)
    return [avg_psnr,avg_ssim,Sam]

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
# # **Testing Model**

# %%
class MemNet(nn.Module):
    def __init__(self, in_channels, channels, num_memblock, num_resblock):
        super(MemNet, self).__init__()
        out_channnels = 1
        self.feature_extractor = BNReLUConv(in_channels, channels)
        self.reconstructor = BNReLUConv(channels, out_channnels)
        self.dense_memory = nn.ModuleList(
            [MemoryBlock(channels, num_resblock, i+1) for i in range(num_memblock)]
        )
        self.freeze_bn = True
        self.freeze_bn_affine = True

    def forward(self, x):
        residual = x
        out = self.feature_extractor(x)
        ys = [out]
        for memory_block in self.dense_memory:
            out = memory_block(out, ys)
        out = self.reconstructor(out)
        # out = out + residual
        return out


class MemoryBlock(nn.Module):
    """Note: num_memblock denotes the number of MemoryBlock currently"""
    def __init__(self, channels, num_resblock, num_memblock):
        super(MemoryBlock, self).__init__()
        self.recursive_unit = nn.ModuleList(
            [ResidualBlock(channels) for i in range(num_resblock)]
        )
        self.gate_unit = BNReLUConv((num_resblock+num_memblock) * channels, channels, 1, 1, 0)

    def forward(self, x, ys):
        """ys is a list which contains long-term memory coming from previous memory block
        xs denotes the short-term memory coming from recursive unit
        """
        xs = []
        residual = x
        for layer in self.recursive_unit:
            x = layer(x)
            xs.append(x)

        gate_out = self.gate_unit(torch.cat(xs+ys, 1))
        ys.append(gate_out)
        return gate_out


class ResidualBlock(torch.nn.Module):

    def __init__(self, channels, k=3, s=1, p=1):
        super(ResidualBlock, self).__init__()
        self.relu_conv1 = BNReLUConv(channels, channels, k, s, p)
        self.relu_conv2 = BNReLUConv(channels, channels, k, s, p)

    def forward(self, x):
        residual = x
        out = self.relu_conv1(x)
        out = self.relu_conv2(out)
        out = out + residual
        return out


class BNReLUConv(nn.Sequential):
    def __init__(self, in_channels, channels, k=3, s=1, p=1, inplace=True):
        super(BNReLUConv, self).__init__()
        self.add_module('bn', nn.BatchNorm2d(in_channels))
        self.add_module('relu', nn.ReLU(inplace=inplace))
        self.add_module('conv', nn.Conv2d(in_channels, channels, k, s, p, bias=False))

# %%
# def memnet():
#   net = MemNet(1, 64, 6, 6)
#   net.use_2dconv = True
#   net.bandwise = False
#   return net

# # # Train and Dataset
# spatial = torch.randn(24, 1, 20, 20)#.cuda()

# model = memnet()#.cuda()
# output = model(spatial)
# output.shape

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %%
TestData = "/content/drive/MyDrive/DC_Mall TestDataset Original_Noise_50_Data.mat"
TrainData = "/content/drive/MyDrive/DC_Mall TrainDataset Original_Noise_50_Augmentation_Data.mat"

#TEST DATA

test_data_DC = scipy.io.loadmat(TestData)
test_data_clean_DC = test_data_DC['original']
test_data_noise_DC = test_data_DC['noise']

#TRAIN DATA
data = scipy.io.loadmat(TrainData)
data_clean = data['original']
data_noise = data['noise']

number, heigth, width, band = data_clean.shape
data = np.zeros((2, number, heigth, width, band))
for n in range(number):
    data[0, n, :, :, :] = data_clean[n, :, :, :]
    data[1, n, :, :, :] = data_noise[n, :, :, :]
data = torch.from_numpy(data.transpose((1, 0, 4, 2, 3)))

# %%
test_data_clean_DC.shape, test_data_noise_DC.shape, data.shape
# Out:
# ((200, 200, 191), (200, 200, 191), torch.Size([24, 2, 191, 20, 20]))

# %%
batch_size = 24
argsK = 24
n_epoch = 100
k = int(argsK/2)

milestone=[180]
lr = 1e-5

cuda = torch.cuda.is_available()
print("cuda is ",cuda)

argument_sigma_role = "sigma_50" # Sigma Noise (5,25,50,75,100)

if os.path.isdir(f"MemNet_Denoising_{argument_sigma_role}"):
  shutil.rmtree(f"MemNet_Denoising_{argument_sigma_role}")
  print(f"Delete MemNet_Denoising_{argument_sigma_role} Folder")
if not os.path.exists(f'MemNet_Denoising_{argument_sigma_role}'):
  os.makedirs(f'MemNet_Denoising_{argument_sigma_role}')
  print(f"Create MemNet_Denoising_{argument_sigma_role} Folder")
else:
  pass

save_dir = os.path.join('model')
if os.path.exists(save_dir):
    shutil.rmtree(save_dir)
    print("Delete Model Folder")
if not os.path.exists(save_dir):
  os.mkdir(save_dir)
  print("Create Model Folder")
else:
  pass

if not os.path.exists(save_dir):
    os.mkdir(save_dir)

DLoader = DataLoader(dataset=data, num_workers=0, drop_last=False, batch_size=batch_size, shuffle=True)

model = MemNet(1, 64, 6, 6)

if cuda:
  model = model.cuda()

criterion = nn.L1Loss().cuda()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = MultiStepLR(optimizer, milestones=milestone, gamma=0.2)
# Out:
# cuda is  True
# Create MemNet_Denoising_sigma_50 Folder
# Create Model Folder

# %%
psnrs_matric, ssims_matric, sams_matric, time_train, time_test = list(), list(), list(), list(), list()
for epoch in range(0, n_epoch):
  model.train()
  lr = optimizer.state_dict()['param_groups'][0]['lr']
  epoch_loss = 0
  start_time = time.time()

  for _, batch_yx in enumerate(DLoader):
    optimizer.zero_grad()
    if cuda:
      batch_x, batch_y = batch_yx[:,0,:,:].cuda(), batch_yx[:,1,:,:].cuda()

    iter_band = np.arange(band)
    np.random.shuffle(iter_band)

    for b in iter_band:
      x = batch_y[:,b, :, :]
      noise_free = batch_x[:,b, :, :]

      x = torch.unsqueeze(x, dim=1).type(torch.FloatTensor)
      noise_free = torch.unsqueeze(noise_free, dim=1).type(torch.FloatTensor)

      if cuda:
        x = x.cuda()
        noise_free = noise_free.cuda()

      learned_image=model(x)
      loss = criterion(learned_image, noise_free)
      epoch_loss += loss.item()
      loss.backward()
      optimizer.step()

  scheduler.step()
  batch_number = data.size(0) // batch_size
  final_time = time.time() - start_time
  time_train.append(final_time)

  if(epoch<n_epoch):
    model.eval()
    data_noise = torch.from_numpy(test_data_noise_DC)
    hight,width,cs=data_noise.shape
    data_noise = data_noise.permute(2, 1, 0)
    test_out = torch.zeros(data_noise.shape).type(torch.FloatTensor)

    start_time_test = time.time()
    for channel_i in range(cs):
      x_data = data_noise[channel_i, :, :]
      x_data = torch.unsqueeze(x_data, dim=0).type(torch.FloatTensor)
      x_data = torch.unsqueeze(x_data, dim=0).type(torch.FloatTensor)

      if cuda:
        x_data = x_data.cuda()
      with torch.no_grad():
        out = model(x_data)

      out = out.squeeze()
      test_out[channel_i,:,:] = out

    end_time_test = time.time() - start_time_test
    time_test.append(end_time_test)

    test_out = test_out.permute(2,1,0)
    denoise_image_out = test_out.cpu().numpy()

    PSNR,SSIM,SAM = quantitative_assess(test_data_clean_DC, denoise_image_out)
    psnrs_matric.append(PSNR)
    ssims_matric.append(SSIM)
    sams_matric.append(SAM)


  total_epoch_loss = epoch_loss / batch_number
  print(f"Epoch : {epoch+1}/{n_epoch} and Loss : ({total_epoch_loss:.5f}) and (PSNR : {PSNR} & SSIM : {SSIM} & SAM : {SAM}) and Train Time : ({final_time:.1f}) Sec and Test Time : ({end_time_test:.1f}) Sec")

  torch.save(model, os.path.join(save_dir, 'model_%03d.pth' % (epoch + 1)))
  checkpoint = {
                'optimizer': optimizer.state_dict(),
                "epoch": epoch,
                'lr_schedule': scheduler.state_dict()
              }
  torch.save(checkpoint, os.path.join(save_dir, 'checkpoint_%03d.pth' % (epoch + 1)))
# Out:
# Epoch : 1/100 and Loss : (33.20724) and (PSNR : -10.611670066205242 & SSIM : 0.2356415680490151 & SAM : 0.4499768614768982) and Train Time : (21.2) Sec and Test Time : (13.7) Sec
# Epoch : 2/100 and Loss : (21.97242) and (PSNR : -0.4728750462766402 & SSIM : 0.3394180037258258 & SAM : 0.4842168986797333) and Train Time : (12.9) Sec and Test Time : (13.9) Sec
# Epoch : 3/100 and Loss : (21.80471) and (PSNR : -12.708730447902871 & SSIM : 0.43560097763899946 & SAM : 1.1574541330337524) and Train Time : (13.6) Sec and Test Time : (14.1) Sec
# Epoch : 4/100 and Loss : (17.14993) and (PSNR : -9.58297300489395 & SSIM : 0.2604104487391048 & SAM : 0.47912469506263733) and Train Time : (13.1) Sec and Test Time : (14.3) Sec
# Epoch : 5/100 and Loss : (20.50038) and (PSNR : 3.4562796220358085 & SSIM : 0.36969630990558405 & SAM : 1.0051922798156738) and Train Time : (13.1) Sec and Test Time : (14.6) Sec
# Epoch : 6/100 and Loss : (19.89208) and (PSNR : 2.323444181204045 & SSIM : 0.3072602024681727 & SAM : 0.9850907921791077) and Train Time : (13.4) Sec and Test Time : (15.1) Sec
# Epoch : 7/100 and Loss : (17.70867) and (PSNR : 0.16217822848527963 & SSIM : 0.48062352795853563 & SAM : 0.3972255289554596) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 8/100 and Loss : (16.63637) and (PSNR : -6.02562787635408 & SSIM : 0.3971738961260543 & SAM : 0.3882809579372406) and Train Time : (13.3) Sec and Test Time : (14.9) Sec
# Epoch : 9/100 and Loss : (17.97507) and (PSNR : 5.616406472094565 & SSIM : 0.4776541544877469 & SAM : 0.5428879261016846) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 10/100 and Loss : (12.82475) and (PSNR : 14.258908370186383 & SSIM : 0.610400569757419 & SAM : 0.3012675344944) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 11/100 and Loss : (12.91043) and (PSNR : 10.993844942252702 & SSIM : 0.42199963394167983 & SAM : 0.44923529028892517) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 12/100 and Loss : (12.45688) and (PSNR : 11.119469928615274 & SSIM : 0.5018230632674014 & SAM : 0.38452666997909546) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 13/100 and Loss : (13.97310) and (PSNR : 9.387565570203801 & SSIM : 0.4656514488546273 & SAM : 0.5533127784729004) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 14/100 and Loss : (14.52138) and (PSNR : 14.497268084523213 & SSIM : 0.6106824910085363 & SAM : 0.24306869506835938) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 15/100 and Loss : (16.53925) and (PSNR : 8.102001316547637 & SSIM : 0.599381490589786 & SAM : 0.3401593863964081) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 16/100 and Loss : (15.21604) and (PSNR : 15.793864331289605 & SSIM : 0.6417297862970904 & SAM : 0.28063052892684937) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 17/100 and Loss : (11.90732) and (PSNR : 14.360355753567596 & SSIM : 0.6087775924437419 & SAM : 0.3041527569293976) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 18/100 and Loss : (13.51047) and (PSNR : 6.07498803583018 & SSIM : 0.43532537332249377 & SAM : 0.5238216519355774) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 19/100 and Loss : (15.57450) and (PSNR : 17.708902582569188 & SSIM : 0.719143124057811 & SAM : 0.2855958640575409) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 20/100 and Loss : (10.27078) and (PSNR : 15.457294522069821 & SSIM : 0.6295174100713797 & SAM : 0.243208646774292) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 21/100 and Loss : (10.99405) and (PSNR : 14.463369150632332 & SSIM : 0.5976506877942817 & SAM : 0.29090091586112976) and Train Time : (13.6) Sec and Test Time : (14.9) Sec
# Epoch : 22/100 and Loss : (12.33676) and (PSNR : 19.24357439580817 & SSIM : 0.729685257868987 & SAM : 0.23731207847595215) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 23/100 and Loss : (10.59079) and (PSNR : 13.247538725057284 & SSIM : 0.5802140292944092 & SAM : 0.36903607845306396) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 24/100 and Loss : (11.84077) and (PSNR : 14.814690467851399 & SSIM : 0.6032645474197631 & SAM : 0.23254616558551788) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 25/100 and Loss : (12.75157) and (PSNR : 10.952144208503515 & SSIM : 0.5273212754366935 & SAM : 0.4870396554470062) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 26/100 and Loss : (11.75394) and (PSNR : 19.016181908076526 & SSIM : 0.7197923007275183 & SAM : 0.2284703552722931) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 27/100 and Loss : (10.34887) and (PSNR : 16.102606917834862 & SSIM : 0.683807029519187 & SAM : 0.24388253688812256) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 28/100 and Loss : (10.87311) and (PSNR : 15.117205171792712 & SSIM : 0.6673319474092281 & SAM : 0.2705196142196655) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 29/100 and Loss : (12.49700) and (PSNR : 18.094846021178515 & SSIM : 0.7223792813238697 & SAM : 0.28376343846321106) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 30/100 and Loss : (9.43600) and (PSNR : 16.015801969941837 & SSIM : 0.6673958549557649 & SAM : 0.2554575800895691) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 31/100 and Loss : (9.72604) and (PSNR : 10.894300284908676 & SSIM : 0.49362760146972656 & SAM : 0.4343172013759613) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 32/100 and Loss : (11.09997) and (PSNR : 14.168525190277862 & SSIM : 0.6684808327715694 & SAM : 0.2750261127948761) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 33/100 and Loss : (11.68501) and (PSNR : 19.010624207369062 & SSIM : 0.7595236795095885 & SAM : 0.22670093178749084) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 34/100 and Loss : (8.46019) and (PSNR : 11.586845079699454 & SSIM : 0.6910990829554546 & SAM : 0.26876750588417053) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 35/100 and Loss : (8.14812) and (PSNR : 19.214293053528234 & SSIM : 0.7533804860662913 & SAM : 0.2186274379491806) and Train Time : (13.6) Sec and Test Time : (15.0) Sec
# Epoch : 36/100 and Loss : (8.41471) and (PSNR : 13.005203958686167 & SSIM : 0.6005542466575466 & SAM : 0.2691977918148041) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 37/100 and Loss : (10.95237) and (PSNR : 7.355932723083284 & SSIM : 0.5203138938424816 & SAM : 0.4615727961063385) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 38/100 and Loss : (11.38200) and (PSNR : 14.885551556827481 & SSIM : 0.6514498564400727 & SAM : 0.31700068712234497) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 39/100 and Loss : (11.65676) and (PSNR : 9.14352057445338 & SSIM : 0.5680670793103488 & SAM : 0.37662988901138306) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 40/100 and Loss : (14.21576) and (PSNR : 10.88987765634708 & SSIM : 0.6621669558186277 & SAM : 0.2685778737068176) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 41/100 and Loss : (10.63598) and (PSNR : 11.007873354353242 & SSIM : 0.6214686961850423 & SAM : 0.3303378224372864) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 42/100 and Loss : (9.67574) and (PSNR : 15.848579495391773 & SSIM : 0.6898908100274795 & SAM : 0.2811933159828186) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 43/100 and Loss : (9.78137) and (PSNR : 10.42861384665592 & SSIM : 0.6176236796799266 & SAM : 0.33309388160705566) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 44/100 and Loss : (10.15328) and (PSNR : 8.418426873376955 & SSIM : 0.5372066210195064 & SAM : 0.3924196660518646) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 45/100 and Loss : (10.79682) and (PSNR : 12.509543536036576 & SSIM : 0.6715637608464099 & SAM : 0.2717905640602112) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 46/100 and Loss : (8.34029) and (PSNR : 15.235046303483905 & SSIM : 0.7049033814860503 & SAM : 0.24449816346168518) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 47/100 and Loss : (9.31065) and (PSNR : 6.555981504762733 & SSIM : 0.5457705257330954 & SAM : 0.40510889887809753) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 48/100 and Loss : (12.11612) and (PSNR : 11.675131921896261 & SSIM : 0.6490824886177249 & SAM : 0.34649214148521423) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 49/100 and Loss : (9.49630) and (PSNR : 16.02807334410817 & SSIM : 0.6735216846657224 & SAM : 0.22022446990013123) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 50/100 and Loss : (10.02855) and (PSNR : 16.024826165824578 & SSIM : 0.7090836159167184 & SAM : 0.22776779532432556) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 51/100 and Loss : (10.36745) and (PSNR : 16.039779332116918 & SSIM : 0.6664296012946257 & SAM : 0.23191708326339722) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 52/100 and Loss : (10.47434) and (PSNR : 15.492668181555795 & SSIM : 0.6892462812359178 & SAM : 0.2445344477891922) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 53/100 and Loss : (10.22945) and (PSNR : 15.716009169469062 & SSIM : 0.661122307793997 & SAM : 0.2494339793920517) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 54/100 and Loss : (9.48164) and (PSNR : 13.717628420540535 & SSIM : 0.6366528479469319 & SAM : 0.3128659129142761) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 55/100 and Loss : (10.30291) and (PSNR : 17.61270264703729 & SSIM : 0.7022488713203675 & SAM : 0.24179697036743164) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 56/100 and Loss : (9.37365) and (PSNR : 15.49696484603171 & SSIM : 0.7131723249337404 & SAM : 0.2330460399389267) and Train Time : (13.5) Sec and Test Time : (14.9) Sec
# Epoch : 57/100 and Loss : (9.24550) and (PSNR : 16.259138330770302 & SSIM : 0.7162563319173514 & SAM : 0.2540426254272461) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 58/100 and Loss : (8.76204) and (PSNR : 13.82934072937399 & SSIM : 0.6878894298217831 & SAM : 0.24556845426559448) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 59/100 and Loss : (9.11972) and (PSNR : 10.820769213813003 & SSIM : 0.6933394592424781 & SAM : 0.3082454800605774) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 60/100 and Loss : (8.66163) and (PSNR : 16.967813106832324 & SSIM : 0.7315023501827743 & SAM : 0.21656765043735504) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 61/100 and Loss : (9.41723) and (PSNR : 2.44114461312812 & SSIM : 0.5929758201324171 & SAM : 0.4237429201602936) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 62/100 and Loss : (8.84382) and (PSNR : 14.646238236920809 & SSIM : 0.6971146980148993 & SAM : 0.23599426448345184) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 63/100 and Loss : (8.25080) and (PSNR : 9.51750384652787 & SSIM : 0.6218228583652808 & SAM : 0.33375710248947144) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 64/100 and Loss : (8.68586) and (PSNR : 15.974105088007805 & SSIM : 0.6960833040344421 & SAM : 0.23119699954986572) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 65/100 and Loss : (9.60399) and (PSNR : 2.5165649917093122 & SSIM : 0.5242853315964204 & SAM : 0.46078765392303467) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 66/100 and Loss : (10.02940) and (PSNR : 17.207243683324144 & SSIM : 0.7260893825449016 & SAM : 0.2337162047624588) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 67/100 and Loss : (8.34851) and (PSNR : 14.397808178643196 & SSIM : 0.6410520254880371 & SAM : 0.25869783759117126) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 68/100 and Loss : (8.84275) and (PSNR : 15.606213893310988 & SSIM : 0.6886708070026218 & SAM : 0.24446384608745575) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 69/100 and Loss : (10.01861) and (PSNR : 4.772644439817573 & SSIM : 0.6112847852224903 & SAM : 0.34750980138778687) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 70/100 and Loss : (9.49852) and (PSNR : 5.3283052189990565 & SSIM : 0.6107188071968691 & SAM : 0.3175346553325653) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 71/100 and Loss : (8.38408) and (PSNR : 13.032700841134163 & SSIM : 0.7202256283934348 & SAM : 0.23802323639392853) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 72/100 and Loss : (8.63521) and (PSNR : 16.826189589254803 & SSIM : 0.7192533832089829 & SAM : 0.21497434377670288) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 73/100 and Loss : (8.81819) and (PSNR : 18.644928501408714 & SSIM : 0.72213174786787 & SAM : 0.2164199948310852) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 74/100 and Loss : (8.84500) and (PSNR : 14.29150586824513 & SSIM : 0.7191043376395411 & SAM : 0.24332457780838013) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 75/100 and Loss : (8.32556) and (PSNR : 18.187740515560076 & SSIM : 0.7415618460868697 & SAM : 0.202819362282753) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 76/100 and Loss : (8.00427) and (PSNR : 13.34486171458994 & SSIM : 0.7016685809664771 & SAM : 0.23764917254447937) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 77/100 and Loss : (8.24123) and (PSNR : 11.626964815778612 & SSIM : 0.6419144951205601 & SAM : 0.28569144010543823) and Train Time : (13.3) Sec and Test Time : (14.9) Sec
# Epoch : 78/100 and Loss : (8.31231) and (PSNR : 13.89550646270439 & SSIM : 0.6954243211352744 & SAM : 0.24342572689056396) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 79/100 and Loss : (9.05448) and (PSNR : 6.094808008997054 & SSIM : 0.5190948042599521 & SAM : 0.4302852153778076) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 80/100 and Loss : (9.40382) and (PSNR : 17.6318559010534 & SSIM : 0.7455149613079176 & SAM : 0.23219475150108337) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 81/100 and Loss : (7.65191) and (PSNR : 18.193985501046257 & SSIM : 0.7055556126972831 & SAM : 0.21729770302772522) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 82/100 and Loss : (7.52069) and (PSNR : 19.196015112697236 & SSIM : 0.7737097145879714 & SAM : 0.2124294936656952) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 83/100 and Loss : (7.42935) and (PSNR : 16.87187795946084 & SSIM : 0.71293698459049 & SAM : 0.20424777269363403) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 84/100 and Loss : (7.85445) and (PSNR : 17.673135566221212 & SSIM : 0.7264719607410112 & SAM : 0.23771503567695618) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 85/100 and Loss : (8.06510) and (PSNR : 14.94756821669565 & SSIM : 0.6401857106437893 & SAM : 0.2356879860162735) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 86/100 and Loss : (8.25997) and (PSNR : 12.38655348028831 & SSIM : 0.6558812780152874 & SAM : 0.24637861549854279) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 87/100 and Loss : (9.20870) and (PSNR : 12.17577856909432 & SSIM : 0.7148166239746515 & SAM : 0.23782271146774292) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 88/100 and Loss : (7.94928) and (PSNR : 18.035779800117076 & SSIM : 0.7385680582218571 & SAM : 0.2240576446056366) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 89/100 and Loss : (7.63789) and (PSNR : 19.163184104543816 & SSIM : 0.7183702093486218 & SAM : 0.2031632959842682) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 90/100 and Loss : (7.95955) and (PSNR : 13.491552953649961 & SSIM : 0.6678665095216555 & SAM : 0.23530322313308716) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 91/100 and Loss : (8.51719) and (PSNR : 8.332763365135026 & SSIM : 0.6084600678627369 & SAM : 0.3116808235645294) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 92/100 and Loss : (9.87388) and (PSNR : 6.542102011766618 & SSIM : 0.6746611407678746 & SAM : 0.2715359926223755) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 93/100 and Loss : (7.69677) and (PSNR : 15.468855178432444 & SSIM : 0.7133973532685473 & SAM : 0.22508025169372559) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 94/100 and Loss : (7.09192) and (PSNR : 15.283346073458492 & SSIM : 0.7574962317206336 & SAM : 0.21621596813201904) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 95/100 and Loss : (7.44570) and (PSNR : 13.730857505068462 & SSIM : 0.6731391212586766 & SAM : 0.23526807129383087) and Train Time : (13.4) Sec and Test Time : (14.9) Sec
# Epoch : 96/100 and Loss : (7.23791) and (PSNR : 11.445617781364438 & SSIM : 0.6850909945639811 & SAM : 0.25607508420944214) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 97/100 and Loss : (7.59670) and (PSNR : 15.926105479771406 & SSIM : 0.662809294650782 & SAM : 0.2177998572587967) and Train Time : (13.5) Sec and Test Time : (15.0) Sec
# Epoch : 98/100 and Loss : (8.69029) and (PSNR : 13.203763123582618 & SSIM : 0.6797319323834355 & SAM : 0.24431508779525757) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 99/100 and Loss : (8.55263) and (PSNR : 19.18016417656515 & SSIM : 0.7157811491106952 & SAM : 0.21844735741615295) and Train Time : (13.4) Sec and Test Time : (15.0) Sec
# Epoch : 100/100 and Loss : (7.32527) and (PSNR : 19.390202618434827 & SSIM : 0.7376621033359728 & SAM : 0.21424482762813568) and Train Time : (13.4) Sec and Test Time : (14.9) Sec

# %%
# psnrs, ssims, sam
psnr_max, psnr_std = np.amax(psnrs_matric), np.std(psnrs_matric, ddof=1)
ssim_max, ssim_std = np.amax(ssims_matric), np.std(ssims_matric, ddof=1)
sam_max, sam_std = np.amin(sams_matric), np.std(sams_matric, ddof=1)
traintime_average, testtime_average = np.average(final_time), np.average(time_test)

from prettytable import PrettyTable
pt = PrettyTable()
print(f"Note: Improvements shown are over original pairs of Hyperspectral Image using {argument_sigma_role}")
pt.field_names = ["Model", "MPSNR", "MSSIM", "MSAM", "TRAIN_TIME", "TESTTIME"]

pt.add_row(["MemNet Denoising Model ","{:.4f} ± {:.4f}".format(psnr_max, psnr_std),"{:.4f} ± {:.4f}".format(ssim_max,ssim_std),"{:.4f} ± {:.4f}".format(sam_max,sam_std), "Average {:.4f}".format(traintime_average), "Average {:.4f}".format(testtime_average)])
data = pt.get_string()
with open(f'./MemNet_Denoising_{argument_sigma_role}/MemNet_Denoising_{argument_sigma_role}.txt', 'w') as f: f.write(data)
print(pt)
# Out:
# Note: Improvements shown are over original pairs of Hyperspectral Image using sigma_50
# +-------------------------+------------------+-----------------+-----------------+-----------------+-----------------+
# |          Model          |      MPSNR       |      MSSIM      |       MSAM      |    TRAIN_TIME   |     TESTTIME    |
# +-------------------------+------------------+-----------------+-----------------+-----------------+-----------------+
# | MemNet Denoising Model  | 19.3902 ± 6.4411 | 0.7737 ± 0.1128 | 0.2028 ± 0.1560 | Average 13.3993 | Average 14.9050 |
# +-------------------------+------------------+-----------------+-----------------+-----------------+-----------------+

# %%
data = {
    "PSNR": psnrs_matric,
    "SSIM": ssims_matric,
    "SAM": sams_matric,
    "TrainTime": final_time,
    "TestTime": time_test,
}
import pandas as pd
data = pd.DataFrame().from_dict(data)
data.to_csv(f'./MemNet_Denoising_{argument_sigma_role}/MemNet_Denoising_PSNR_SSIM_SAM_BANDS_CSVFILE_{argument_sigma_role}.csv', index=False)
data
# Out:
#          PSNR      SSIM       SAM  TrainTime   TestTime
# 0  -10.611670  0.235642  0.449977  13.399311  13.725611
# 1   -0.472875  0.339418  0.484217  13.399311  13.924546
# 2  -12.708730  0.435601  1.157454  13.399311  14.113174
# 3   -9.582973  0.260410  0.479125  13.399311  14.254193
# 4    3.456280  0.369696  1.005192  13.399311  14.581453
# ..        ...       ...       ...        ...        ...
# 95  11.445618  0.685091  0.256075  13.399311  14.962520
# 96  15.926105  0.662809  0.217800  13.399311  14.971623
# 97  13.203763  0.679732  0.244315  13.399311  14.959450
# 98  19.180164  0.715781  0.218447  13.399311  14.981877
# 99  19.390203  0.737662  0.214245  13.399311  14.940254
#
# [100 rows x 5 columns]

# %%
epochs = range(0, 100)
plt.plot(epochs, psnrs_matric, 'b', label='MPSNR')
plt.title(f'MPSNR with {argument_sigma_role}')
plt.xlabel('Bands')
plt.ylabel('MPSNR')
plt.legend()
plt.xlim(0,100)
plt.savefig(f'./MemNet_Denoising_{argument_sigma_role}/MemNet_Denoising_Graph_MPSNR_{argument_sigma_role}.png')
plt.show()

# %%
epochs = range(0, 100)
plt.plot(epochs, ssims_matric, 'b', label='MSSIM')
plt.title(f'MSSIM with {argument_sigma_role}')
plt.xlabel('Bands')
plt.ylabel('MSSIM')
plt.legend()
plt.xlim(0,100)
plt.savefig(f'./MemNet_Denoising_{argument_sigma_role}/MemNet_Denoising_Graph_MSSIM_{argument_sigma_role}.png')
plt.show()

# %%
epochs = range(0, 100)
plt.plot(epochs, sams_matric, 'b', label='MSAM')
plt.title(f'MSAM with {argument_sigma_role}')
plt.xlabel('Bands')
plt.ylabel('MSAM')
plt.legend()
plt.xlim(0,100)
plt.savefig(f'./MemNet_Denoising_{argument_sigma_role}/MemNet_Denoising_Graph_MSAM_{argument_sigma_role}.png')
plt.show()

# %%
def show_image(data_noise,test_out,data_clean):
  def Noise_Image():
    fig = plt.figure(frameon=False, figsize = (5, 5))
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fig.add_axes(ax)
    plt.imshow(data_noise[:, :, (56,25,16)])
    plt.savefig(f"./MemNet_Denoising_{argument_sigma_role}/DCMaLL_Noise_{argument_sigma_role}.png")
    plt.axis('off')
    plt.title('noise image')
  def Denoise_Image():
    fig = plt.figure(frameon=False, figsize = (5, 5))
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fig.add_axes(ax)
    plt.imshow(test_out[:, :, (56,25,16)])
    plt.savefig(f"./MemNet_Denoising_{argument_sigma_role}/DCMaLL_Denoise_{argument_sigma_role}.png")
    plt.axis('off')
    plt.title('denoise image')
  def Clean_Image():
    fig = plt.figure(frameon=False, figsize = (5, 5))
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    fig.add_axes(ax)
    plt.imshow(data_clean[:, :, (56,25,16)])
    plt.savefig(f"./MemNet_Denoising_{argument_sigma_role}/DCMaLL_Clean_{argument_sigma_role}.png")
    plt.axis('off')
    plt.title('clean image')

  Noise_Image()
  Denoise_Image()
  Clean_Image()
  plt.show()

# %%
show_image(test_data_noise_DC,denoise_image_out,test_data_clean_DC)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
scipy.io.savemat(f"./MemNet_Denoising_{argument_sigma_role}/Washington DC Mall University_Denoise_{argument_sigma_role}_Dataset_Image.mat",{'Image': denoise_image_out})
